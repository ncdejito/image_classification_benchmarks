# %% [markdown]
# How to use:
# * `python3 train.py --data-path $DATA_PATH` (DATA_PATH must have train and val folders inside)
# * `python3 inference.py --input_dir=example_directory_structure/input --output_dir=example_directory_structure/output`

# %% [markdown]
# ## Load data

# %%
from google.colab import drive
drive.mount('/gdrive')
# !cp "/gdrive/My Drive/files/work/applications/company/CV_ML_take_home_task.zip" .

# !unzip CV_ML_take_home_task.zip
# Out:
# Mounted at /gdrive
# Archive:  CV_ML_take_home_task.zip
#   inflating: CV_ML_take_home_task/CVML_take_home_task.docx
#    creating: CV_ML_take_home_task/example_directory_structure/
#    creating: CV_ML_take_home_task/example_directory_structure/input/
#    creating: CV_ML_take_home_task/example_directory_structure/output/
#    creating: CV_ML_take_home_task/example_directory_structure/output/1/
#    creating: CV_ML_take_home_task/example_directory_structure/output/2/
#    creating: CV_ML_take_home_task/screws_set/
#    creating: CV_ML_take_home_task/screws_set/test/
#    creating: CV_ML_take_home_task/screws_set/test/1/
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_10.927623.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_12.161348.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_16.113069.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_17.093084.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_17.808800.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_18.479928.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_19.092295.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_19.793988.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_27.277979.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_27.925022.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_28.572377.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_29.241113.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_29.896233.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_30.554868.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_31.154879.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_31.776882.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_32.461417.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_33.145520.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_33.809394.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_34.477436.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_35.155557.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_35.894874.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_36.650230.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_37.340870.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_38.057286.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_38.802739.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_39.455253.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_40.090292.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_40.745298.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_41.412432.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_42.048823.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_42.687966.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_43.291092.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_43.872582.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_44.478352.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_45.124888.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_45.754623.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_46.414919.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_47.054766.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_47.684786.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_48.349162.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_48.956804.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_49.540295.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_50.245536.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_50.989331.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_51.707988.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_52.440076.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_13_img_2020-01-29 18_59_53.134375.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_14_img_2020-01-29 18_59_54.223402.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_14_img_2020-01-29 18_59_55.697094.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_14_img_2020-01-29 18_59_57.097270.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_14_img_2020-01-29 18_59_58.652407.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_01.830283.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_02.507792.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_03.255165.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_03.989373.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_04.690187.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_05.351720.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_06.025328.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_06.754846.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_07.422491.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_08.016235.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_08.632471.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_09.211866.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_09.823302.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_10.525325.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_11.249330.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_11.973910.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_12.717397.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_13.366292.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_14.017367.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_14.657303.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_15.899433.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_16.581785.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_17.290093.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_17.960376.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_18.657319.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_19.428941.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_20.101016.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_20.800347.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_21.565146.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_22.345903.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_23.046395.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_23.667982.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_24.301472.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_24.925719.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_25.617396.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_27.000938.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_27.635254.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_28.297421.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_29.692415.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_30.416539.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_31.168401.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_31.835805.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_32.538411.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_33.223081.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_33.972266.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/1/set_23_img_2020-02-28 18_00_35.495757.jpeg
#    creating: CV_ML_take_home_task/screws_set/test/2/
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_54_50.505570.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_54_50.971989.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_54_51.363943.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_54_51.781801.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_54_53.358545.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_54_53.788190.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_54_54.214387.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_54_54.629420.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_54_55.015868.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_54_55.395499.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_54_55.802682.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_54_56.231744.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_54_56.660366.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_54_57.890998.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_54_58.272220.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_54_58.665625.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_54_59.068508.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_54_59.477673.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_54_59.904199.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_00.340350.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_01.142637.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_01.540200.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_01.952801.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_02.355095.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_02.760941.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_03.188336.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_03.639462.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_04.099030.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_04.519937.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_05.761714.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_06.175015.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_06.590125.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_07.022912.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_07.428593.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_07.813788.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_08.215276.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_08.600409.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_08.981564.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_09.382217.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_09.770046.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_10.170084.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_10.627072.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_11.049355.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_26_img_2020-05-21 16_55_11.452052.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_21.393578.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_23.163952.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_25.143230.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_25.589871.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_26.037616.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_26.435647.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_26.831631.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_27.240596.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_28.668176.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_29.051220.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_29.470950.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_29.903591.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_30.325754.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_30.749313.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_31.175384.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_31.605529.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_32.009329.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_33.145924.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_34.285533.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_34.745368.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_35.192677.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_35.600493.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_36.001380.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_36.418620.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_36.813868.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_37.212835.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_37.639581.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_39.154669.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_39.592163.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_28_img_2020-05-21 16_55_40.022166.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_42.902203.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_43.276840.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_44.669918.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_45.061979.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_45.440731.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_45.836554.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_46.254770.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_46.671624.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_47.503364.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_47.894807.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_48.284609.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_48.695326.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_49.106871.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_49.535427.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_50.850258.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_51.289395.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_51.728518.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_52.171219.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_52.594057.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_53.816542.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_54.227957.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_54.641533.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_55.068760.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_55.500578.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_56.767226.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_57.156087.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_57.560538.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_57.973251.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_58.377375.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_58.774542.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_59.546810.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_55_59.978784.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_56_00.404027.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_56_00.843482.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_56_01.285954.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_56_01.689549.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_56_02.492433.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_56_02.874826.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_56_03.241922.jpeg
#   inflating: CV_ML_take_home_task/screws_set/test/2/set_30_img_2020-05-21 16_56_03.667818.jpeg
#    creating: CV_ML_take_home_task/screws_set/train/
#    creating: CV_ML_take_home_task/screws_set/train/1/
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_00.217115.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_00.855531.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_01.509054.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_02.180978.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_02.839948.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_03.455979.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_04.044298.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_04.671883.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_05.297558.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_05.931470.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_06.816074.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_07.698597.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_08.336866.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_08.976974.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_09.644891.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_10.381645.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_11.111233.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_14.382799.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_15.042274.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_15.664862.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_16.305835.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_16.942949.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_17.606431.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_18.245265.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_18.888833.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_19.525167.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_20.133666.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_20.781106.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_21.470432.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_22.357762.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_23.303731.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_24.021392.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_24.686235.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_25.372843.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_26.035672.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_26.637830.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_27.290535.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_28.009136.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_28.717532.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_29.397950.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_30.054316.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_30.668714.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_31.386935.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_32.075171.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_32.755136.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_33.412984.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_34.033958.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_34.652606.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_35.365285.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_36.021733.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_36.642954.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_1_img_2020-01-29 15_42_37.653262.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_56_45.188820.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_56_45.963378.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_56_46.673524.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_56_47.311548.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_56_48.018684.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_56_48.746505.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_56_49.385714.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_56_49.996714.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_56_50.614617.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_00.005378.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_00.735669.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_01.439237.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_02.080139.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_02.733443.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_03.408667.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_03.997925.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_04.598656.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_05.230318.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_05.867535.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_06.539267.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_07.208301.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_07.848353.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_08.518429.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_09.230189.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_09.873033.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_10.439021.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_11.032547.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_11.672853.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_12.337839.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_13.019071.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_13.726937.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_14.417796.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_15.085198.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_15.824204.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_16.671559.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_17.484036.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_18.111779.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_18.698014.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_19.353359.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_20.028830.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_20.739189.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_28.048394.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_28.721758.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_29.370164.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_29.997425.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_30.611422.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_31.213787.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_31.979336.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_32.784223.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_33.415045.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_34.025283.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_34.716077.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_35.407812.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_10_img_2020-01-29 18_57_36.036944.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_41.700856.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_42.368266.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_43.035126.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_43.705211.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_44.363278.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_44.949320.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_45.510962.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_46.116852.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_46.746181.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_47.501536.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_48.291018.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_48.944910.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_49.649990.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_50.333465.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_50.988790.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_51.632328.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_52.286902.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_52.924222.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_53.597525.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_54.282006.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_54.961864.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_55.619287.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_56.301234.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_57.009775.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_57.729627.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_58.402332.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_59.116850.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_57_59.873696.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_00.609763.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_01.245602.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_01.861645.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_02.432704.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_03.193930.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_04.005947.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_04.664924.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_05.321590.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_06.012836.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_06.712697.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_07.356514.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_07.988069.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_08.568695.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_09.190914.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_09.849297.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_10.537651.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_11.182473.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_11.817623.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_12.431551.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_13.036746.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_13.731241.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_14.405618.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_15.032863.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_15.674222.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_16.340005.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_16.972798.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_17.688189.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_11_img_2020-01-29 18_58_18.558114.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_19.684572.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_20.832598.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_26.822799.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_27.540446.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_28.215354.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_28.889811.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_29.536419.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_30.258903.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_30.930844.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_31.482261.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_32.042628.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_32.702730.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_33.383716.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_34.126712.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_34.891835.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_35.505099.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_36.127038.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_36.733796.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_37.352328.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_38.010625.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_38.681359.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_39.358440.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_40.084870.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_40.782613.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_41.490752.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_42.213689.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_42.887606.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_43.540969.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_44.200692.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_44.836692.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_45.459647.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_46.083677.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_46.735211.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_47.377273.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_48.010810.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_48.582596.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_49.148283.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_58.565856.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_59.272401.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_58_59.965128.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_59_00.621083.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_59_01.268574.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_59_01.826264.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_59_02.379379.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_59_03.058172.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_59_03.772798.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_59_04.412531.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_59_05.211883.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_59_06.145221.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_59_06.823563.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_59_07.417499.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_59_07.992826.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_59_08.576376.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_59_09.204078.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_12_img_2020-01-29 18_59_09.949322.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_42_56.837073.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_42_57.472956.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_42_58.159773.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_42_58.878275.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_42_59.544791.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_00.135831.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_00.769338.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_01.395201.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_02.005484.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_02.699103.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_03.332000.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_03.941682.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_04.594225.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_05.209360.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_05.893673.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_06.569610.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_07.248044.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_16.385794.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_17.046873.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_17.700201.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_18.284200.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_18.965109.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_19.680922.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_20.370684.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_21.054575.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_21.780995.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_22.461483.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_23.042044.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_23.696089.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_24.515490.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_25.319745.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_25.982741.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_26.608889.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_27.280906.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_27.986530.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_28.683769.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_29.309766.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_29.917575.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_30.592848.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_31.224096.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_31.792839.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_32.327460.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_32.927135.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_33.586638.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_34.193801.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_34.860335.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_35.578083.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_36.198761.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_36.832352.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_37.488735.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_38.104137.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_2_img_2020-01-29 15_43_38.826311.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_3_img_2020-01-29 15_43_49.769662.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_3_img_2020-01-29 15_43_50.556027.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_3_img_2020-01-29 15_43_51.290344.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/1/set_3_img_2020-01-29 15_43_52.024919.jpeg
# ...
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_17.444542.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_18.076101.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_18.696476.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_19.306045.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_19.938260.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_20.607237.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_21.236779.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_21.805049.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_22.414829.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_23.120863.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_23.820889.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_24.447559.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_25.097252.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_25.704645.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_26.333252.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_27.001072.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_27.700352.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_28.334812.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_28.922075.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_29.686923.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_30.500626.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_31.198260.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_31.885819.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_38.865849.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_39.641706.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_40.388718.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_41.040365.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_41.619132.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_42.164563.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_42.744276.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_43.431901.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_44.114417.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_44.776796.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_45.462161.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_46.215480.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_46.887490.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_47.575565.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_48.186170.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_48.824882.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_49.438310.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_50.052525.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_6_img_2020-01-29 14_27_50.900827.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_27_52.036992.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_27_53.265845.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_27_54.524864.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_27_55.905719.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_27_57.260634.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_27_58.560592.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_27_59.877019.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_01.584713.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_07.100039.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_08.728881.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_10.235082.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_11.284627.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_12.161863.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_12.916485.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_13.591628.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_14.240349.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_14.910682.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_15.568172.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_16.254656.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_16.998756.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_17.689876.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_18.352842.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_19.037062.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_19.700001.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_20.384416.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_21.052663.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_21.719117.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_22.375905.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_23.023887.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_23.654430.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_24.337214.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_24.953190.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_25.587521.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_26.320607.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_27.024639.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_27.652035.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_28.309159.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_28.953724.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_29.568059.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_30.177137.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_30.780623.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_31.440771.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_32.222456.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_32.985530.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_33.698093.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_34.394404.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_36.141122.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_36.746262.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_37.408799.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_38.092931.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_38.720387.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_39.365195.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_39.982810.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_7_img_2020-01-29 14_28_40.600679.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_28_41.783955.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_28_43.276330.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_28_44.449385.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_28_45.676845.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_28_46.992286.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_28_50.816920.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_28_52.121673.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_28_53.187840.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_28_53.996789.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_28_54.667674.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_28_55.308325.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_28_55.968771.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_28_56.686629.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_28_57.360866.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_28_58.050823.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_28_58.808525.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_28_59.584040.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_00.288768.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_00.984157.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_09.387669.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_09.964805.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_10.606763.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_11.218235.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_11.877774.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_12.525612.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_13.253198.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_13.936202.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_14.624750.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_15.320082.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_16.001616.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_16.637415.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_17.271420.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_17.954195.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_18.650486.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_19.447775.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_20.268081.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_21.049816.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_21.706313.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_22.369263.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_23.039076.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_23.677530.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_24.376162.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_25.182096.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_25.972460.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_26.698041.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_27.438770.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_28.169738.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_28.842508.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_8_img_2020-01-29 14_29_29.491168.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_9_img_2020-01-29 14_29_30.566154.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_9_img_2020-01-29 14_29_39.054520.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_9_img_2020-01-29 14_29_40.581398.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_9_img_2020-01-29 14_29_41.983616.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_9_img_2020-01-29 14_29_43.509458.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_9_img_2020-01-29 14_29_44.812648.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_9_img_2020-01-29 14_29_46.126514.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_9_img_2020-01-29 14_29_47.385368.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_9_img_2020-01-29 14_29_48.597631.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_9_img_2020-01-29 14_29_50.132159.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_9_img_2020-01-29 14_29_51.706182.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_9_img_2020-01-29 14_29_52.965634.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_9_img_2020-01-29 14_29_54.394162.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_9_img_2020-01-29 14_29_55.945846.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_9_img_2020-01-29 14_29_57.353710.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_9_img_2020-01-29 14_29_58.730933.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_9_img_2020-01-29 14_30_00.090811.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_9_img_2020-01-29 14_30_01.614204.jpeg
#   inflating: CV_ML_take_home_task/screws_set/train/2/set_9_img_2020-01-29 14_30_02.983874.jpeg

# %% [markdown]
# ## Setup env

# %%
data_path = "CV_ML_take_home_task/screws_set"
train_dir = data_path + "/train/"
val_dir = data_path + "/val/"

infer_path = "CV_ML_take_home_task/example_directory_structure"
input_dir = infer_path + "/input"
output_dir = infer_path + "/output"

import os
os.environ["DATA_PATH"] = data_path
os.environ["INFER_PATH"] = infer_path

# copy utility scripts
# !git clone https://github.com/pytorch/vision
# !cp vision/references/classification/* .
# !rm -r vision

# fit convention of used torch script
# !mv CV_ML_take_home_task/screws_set/test CV_ML_take_home_task/screws_set/val
# Out:
# Cloning into 'vision'...
# remote: Enumerating objects: 99439, done.
# remote: Counting objects: 100% (34570/34570), done.
# remote: Compressing objects: 100% (2744/2744), done.
# remote: Total 99439 (delta 31940), reused 33976 (delta 31645), pack-reused 64869
# Receiving objects: 100% (99439/99439), 196.68 MiB | 14.18 MiB/s, done.
# Resolving deltas: 100% (85019/85019), done.

# %% [markdown]
# ## train.py

# %%
script1 = """
# https://github.com/pytorch/vision/tree/main/references/classification
# changes:
# - replace acc5 with acc2
import datetime
import os
import time
import warnings

import presets
import torch
import torch.utils.data
import torchvision
import transforms
import utils
from sampler import RASampler
from torch import nn
from torch.utils.data.dataloader import default_collate
from torchvision.transforms.functional import InterpolationMode


try:
    from torchvision import prototype
except ImportError:
    prototype = None


def train_one_epoch(model, criterion, optimizer, data_loader, device, epoch, args, model_ema=None, scaler=None):
    model.train()
    metric_logger = utils.MetricLogger(delimiter="  ")
    metric_logger.add_meter("lr", utils.SmoothedValue(window_size=1, fmt="{value}"))
    metric_logger.add_meter("img/s", utils.SmoothedValue(window_size=10, fmt="{value}"))

    header = f"Epoch: [{epoch}]"
    for i, (image, target) in enumerate(metric_logger.log_every(data_loader, args.print_freq, header)):
        start_time = time.time()
        image, target = image.to(device), target.to(device)
        with torch.cuda.amp.autocast(enabled=scaler is not None):
            output = model(image)
            loss = criterion(output, target)

        optimizer.zero_grad()
        if scaler is not None:
            scaler.scale(loss).backward()
            if args.clip_grad_norm is not None:
                # we should unscale the gradients of optimizer's assigned params if do gradient clipping
                scaler.unscale_(optimizer)
                nn.utils.clip_grad_norm_(model.parameters(), args.clip_grad_norm)
            scaler.step(optimizer)
            scaler.update()
        else:
            loss.backward()
            if args.clip_grad_norm is not None:
                nn.utils.clip_grad_norm_(model.parameters(), args.clip_grad_norm)
            optimizer.step()

        if model_ema and i % args.model_ema_steps == 0:
            model_ema.update_parameters(model)
            if epoch < args.lr_warmup_epochs:
                # Reset ema buffer to keep copying weights during warmup period
                model_ema.n_averaged.fill_(0)

        acc1, acc2 = utils.accuracy(output, target, topk=(1, 2))
        batch_size = image.shape[0]
        metric_logger.update(loss=loss.item(), lr=optimizer.param_groups[0]["lr"])
        metric_logger.meters["acc1"].update(acc1.item(), n=batch_size)
        metric_logger.meters["acc2"].update(acc2.item(), n=batch_size)
        metric_logger.meters["img/s"].update(batch_size / (time.time() - start_time))


def evaluate(model, criterion, data_loader, device, print_freq=100, log_suffix=""):
    model.eval()
    metric_logger = utils.MetricLogger(delimiter="  ")
    header = f"Test: {log_suffix}"

    num_processed_samples = 0
    with torch.inference_mode():
        for image, target in metric_logger.log_every(data_loader, print_freq, header):
            image = image.to(device, non_blocking=True)
            target = target.to(device, non_blocking=True)
            output = model(image)
            loss = criterion(output, target)

            acc1, acc2 = utils.accuracy(output, target, topk=(1, 2))
            # FIXME need to take into account that the datasets
            # could have been padded in distributed setup
            batch_size = image.shape[0]
            metric_logger.update(loss=loss.item())
            metric_logger.meters["acc1"].update(acc1.item(), n=batch_size)
            metric_logger.meters["acc2"].update(acc2.item(), n=batch_size)
            num_processed_samples += batch_size
    # gather the stats from all processes

    num_processed_samples = utils.reduce_across_processes(num_processed_samples)
    if (
        hasattr(data_loader.dataset, "__len__")
        and len(data_loader.dataset) != num_processed_samples
        and torch.distributed.get_rank() == 0
    ):
        # See FIXME above
        warnings.warn(
            f"It looks like the dataset has {len(data_loader.dataset)} samples, but {num_processed_samples} "
            "samples were used for the validation, which might bias the results. "
            "Try adjusting the batch size and / or the world size. "
            "Setting the world size to 1 is always a safe bet."
        )

    metric_logger.synchronize_between_processes()

    print(f"{header} Acc@1 {metric_logger.acc1.global_avg:.3f} Acc@2 {metric_logger.acc2.global_avg:.3f}")
    return metric_logger.acc1.global_avg


def _get_cache_path(filepath):
    import hashlib

    h = hashlib.sha1(filepath.encode()).hexdigest()
    cache_path = os.path.join("~", ".torch", "vision", "datasets", "imagefolder", h[:10] + ".pt")
    cache_path = os.path.expanduser(cache_path)
    return cache_path


def load_data(traindir, valdir, args):
    # Data loading code
    print("Loading data")
    val_resize_size, val_crop_size, train_crop_size = args.val_resize_size, args.val_crop_size, args.train_crop_size
    interpolation = InterpolationMode(args.interpolation)

    print("Loading training data")
    st = time.time()
    cache_path = _get_cache_path(traindir)
    if args.cache_dataset and os.path.exists(cache_path):
        # Attention, as the transforms are also cached!
        print(f"Loading dataset_train from {cache_path}")
        dataset, _ = torch.load(cache_path)
    else:
        auto_augment_policy = getattr(args, "auto_augment", None)
        random_erase_prob = getattr(args, "random_erase", 0.0)
        dataset = torchvision.datasets.ImageFolder(
            traindir,
            presets.ClassificationPresetTrain(
                crop_size=train_crop_size,
                interpolation=interpolation,
                auto_augment_policy=auto_augment_policy,
                random_erase_prob=random_erase_prob,
            ),
        )
        if args.cache_dataset:
            print(f"Saving dataset_train to {cache_path}")
            utils.mkdir(os.path.dirname(cache_path))
            utils.save_on_master((dataset, traindir), cache_path)
    print("Took", time.time() - st)

    print("Loading validation data")
    cache_path = _get_cache_path(valdir)
    if args.cache_dataset and os.path.exists(cache_path):
        # Attention, as the transforms are also cached!
        print(f"Loading dataset_test from {cache_path}")
        dataset_test, _ = torch.load(cache_path)
    else:
        if not args.prototype:
            preprocessing = presets.ClassificationPresetEval(
                crop_size=val_crop_size, resize_size=val_resize_size, interpolation=interpolation
            )
        else:
            if args.weights:
                weights = prototype.models.get_weight(args.weights)
                preprocessing = weights.transforms()
            else:
                preprocessing = prototype.transforms.ImageNetEval(
                    crop_size=val_crop_size, resize_size=val_resize_size, interpolation=interpolation
                )

        dataset_test = torchvision.datasets.ImageFolder(
            valdir,
            preprocessing,
        )
        if args.cache_dataset:
            print(f"Saving dataset_test to {cache_path}")
            utils.mkdir(os.path.dirname(cache_path))
            utils.save_on_master((dataset_test, valdir), cache_path)

    print("Creating data loaders")
    if args.distributed:
        if hasattr(args, "ra_sampler") and args.ra_sampler:
            train_sampler = RASampler(dataset, shuffle=True, repetitions=args.ra_reps)
        else:
            train_sampler = torch.utils.data.distributed.DistributedSampler(dataset)
        test_sampler = torch.utils.data.distributed.DistributedSampler(dataset_test, shuffle=False)
    else:
        train_sampler = torch.utils.data.RandomSampler(dataset)
        test_sampler = torch.utils.data.SequentialSampler(dataset_test)

    return dataset, dataset_test, train_sampler, test_sampler


def main(args):
    if args.prototype and prototype is None:
        raise ImportError("The prototype module couldn't be found. Please install the latest torchvision nightly.")
    if not args.prototype and args.weights:
        raise ValueError("The weights parameter works only in prototype mode. Please pass the --prototype argument.")
    if args.output_dir:
        utils.mkdir(args.output_dir)

    utils.init_distributed_mode(args)
    print(args)

    device = torch.device(args.device)

    if args.use_deterministic_algorithms:
        torch.backends.cudnn.benchmark = False
        torch.use_deterministic_algorithms(True)
    else:
        torch.backends.cudnn.benchmark = True

    train_dir = os.path.join(args.data_path, "train")
    val_dir = os.path.join(args.data_path, "val")
    dataset, dataset_test, train_sampler, test_sampler = load_data(train_dir, val_dir, args)

    collate_fn = None
    num_classes = len(dataset.classes)
    mixup_transforms = []
    if args.mixup_alpha > 0.0:
        mixup_transforms.append(transforms.RandomMixup(num_classes, p=1.0, alpha=args.mixup_alpha))
    if args.cutmix_alpha > 0.0:
        mixup_transforms.append(transforms.RandomCutmix(num_classes, p=1.0, alpha=args.cutmix_alpha))
    if mixup_transforms:
        mixupcutmix = torchvision.transforms.RandomChoice(mixup_transforms)
        collate_fn = lambda batch: mixupcutmix(*default_collate(batch))  # noqa: E731
    data_loader = torch.utils.data.DataLoader(
        dataset,
        batch_size=args.batch_size,
        sampler=train_sampler,
        num_workers=args.workers,
        pin_memory=True,
        collate_fn=collate_fn,
    )
    data_loader_test = torch.utils.data.DataLoader(
        dataset_test, batch_size=args.batch_size, sampler=test_sampler, num_workers=args.workers, pin_memory=True
    )

    print("Creating model")
    if not args.prototype:
        model = torchvision.models.__dict__[args.model](pretrained=args.pretrained, num_classes=num_classes)
    else:
        model = prototype.models.__dict__[args.model](weights=args.weights, num_classes=num_classes)
    model.to(device)

    if args.distributed and args.sync_bn:
        model = torch.nn.SyncBatchNorm.convert_sync_batchnorm(model)

    criterion = nn.CrossEntropyLoss(label_smoothing=args.label_smoothing)

    if args.norm_weight_decay is None:
        parameters = model.parameters()
    else:
        param_groups = torchvision.ops._utils.split_normalization_params(model)
        wd_groups = [args.norm_weight_decay, args.weight_decay]
        parameters = [{"params": p, "weight_decay": w} for p, w in zip(param_groups, wd_groups) if p]

    opt_name = args.opt.lower()
    if opt_name.startswith("sgd"):
        optimizer = torch.optim.SGD(
            parameters,
            lr=args.lr,
            momentum=args.momentum,
            weight_decay=args.weight_decay,
            nesterov="nesterov" in opt_name,
        )
    elif opt_name == "rmsprop":
        optimizer = torch.optim.RMSprop(
            parameters, lr=args.lr, momentum=args.momentum, weight_decay=args.weight_decay, eps=0.0316, alpha=0.9
        )
    elif opt_name == "adamw":
        optimizer = torch.optim.AdamW(parameters, lr=args.lr, weight_decay=args.weight_decay)
    else:
        raise RuntimeError(f"Invalid optimizer {args.opt}. Only SGD, RMSprop and AdamW are supported.")

    scaler = torch.cuda.amp.GradScaler() if args.amp else None

    args.lr_scheduler = args.lr_scheduler.lower()
    if args.lr_scheduler == "steplr":
        main_lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=args.lr_step_size, gamma=args.lr_gamma)
    elif args.lr_scheduler == "cosineannealinglr":
        main_lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
            optimizer, T_max=args.epochs - args.lr_warmup_epochs
        )
    elif args.lr_scheduler == "exponentiallr":
        main_lr_scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=args.lr_gamma)
    else:
        raise RuntimeError(
            f"Invalid lr scheduler '{args.lr_scheduler}'. Only StepLR, CosineAnnealingLR and ExponentialLR "
            "are supported."
        )

    if args.lr_warmup_epochs > 0:
        if args.lr_warmup_method == "linear":
            warmup_lr_scheduler = torch.optim.lr_scheduler.LinearLR(
                optimizer, start_factor=args.lr_warmup_decay, total_iters=args.lr_warmup_epochs
            )
        elif args.lr_warmup_method == "constant":
            warmup_lr_scheduler = torch.optim.lr_scheduler.ConstantLR(
                optimizer, factor=args.lr_warmup_decay, total_iters=args.lr_warmup_epochs
            )
        else:
            raise RuntimeError(
                f"Invalid warmup lr method '{args.lr_warmup_method}'. Only linear and constant are supported."
            )
        lr_scheduler = torch.optim.lr_scheduler.SequentialLR(
            optimizer, schedulers=[warmup_lr_scheduler, main_lr_scheduler], milestones=[args.lr_warmup_epochs]
        )
    else:
        lr_scheduler = main_lr_scheduler

    model_without_ddp = model
    if args.distributed:
        model = torch.nn.parallel.DistributedDataParallel(model, device_ids=[args.gpu])
        model_without_ddp = model.module

    model_ema = None
    if args.model_ema:
        # Decay adjustment that aims to keep the decay independent from other hyper-parameters originally proposed at:
        # https://github.com/facebookresearch/pycls/blob/f8cd9627/pycls/core/net.py#L123
        #
        # total_ema_updates = (Dataset_size / n_GPUs) * epochs / (batch_size_per_gpu * EMA_steps)
        # We consider constant = Dataset_size for a given dataset/setup and ommit it. Thus:
        # adjust = 1 / total_ema_updates ~= n_GPUs * batch_size_per_gpu * EMA_steps / epochs
        adjust = args.world_size * args.batch_size * args.model_ema_steps / args.epochs
        alpha = 1.0 - args.model_ema_decay
        alpha = min(1.0, alpha * adjust)
        model_ema = utils.ExponentialMovingAverage(model_without_ddp, device=device, decay=1.0 - alpha)

    if args.resume:
        checkpoint = torch.load(args.resume, map_location="cpu")
        model_without_ddp.load_state_dict(checkpoint["model"])
        if not args.test_only:
            optimizer.load_state_dict(checkpoint["optimizer"])
            lr_scheduler.load_state_dict(checkpoint["lr_scheduler"])
        args.start_epoch = checkpoint["epoch"] + 1
        if model_ema:
            model_ema.load_state_dict(checkpoint["model_ema"])
        if scaler:
            scaler.load_state_dict(checkpoint["scaler"])

    if args.test_only:
        # We disable the cudnn benchmarking because it can noticeably affect the accuracy
        torch.backends.cudnn.benchmark = False
        torch.backends.cudnn.deterministic = True
        if model_ema:
            evaluate(model_ema, criterion, data_loader_test, device=device, log_suffix="EMA")
        else:
            evaluate(model, criterion, data_loader_test, device=device)
        return

    print("Start training")
    start_time = time.time()
    for epoch in range(args.start_epoch, args.epochs):
        if args.distributed:
            train_sampler.set_epoch(epoch)
        train_one_epoch(model, criterion, optimizer, data_loader, device, epoch, args, model_ema, scaler)
        lr_scheduler.step()
        evaluate(model, criterion, data_loader_test, device=device)
        if model_ema:
            evaluate(model_ema, criterion, data_loader_test, device=device, log_suffix="EMA")
        if args.output_dir:
            checkpoint = {
                "model": model_without_ddp.state_dict(),
                "optimizer": optimizer.state_dict(),
                "lr_scheduler": lr_scheduler.state_dict(),
                "epoch": epoch,
                "args": args,
            }
            if model_ema:
                checkpoint["model_ema"] = model_ema.state_dict()
            if scaler:
                checkpoint["scaler"] = scaler.state_dict()
            utils.save_on_master(checkpoint, os.path.join(args.output_dir, f"model_{epoch}.pth"))
            utils.save_on_master(checkpoint, os.path.join(args.output_dir, "checkpoint.pth"))

    total_time = time.time() - start_time
    total_time_str = str(datetime.timedelta(seconds=int(total_time)))
    print(f"Training time {total_time_str}")


def get_args_parser(add_help=True):
    import argparse

    parser = argparse.ArgumentParser(description="PyTorch Classification Training", add_help=add_help)

    parser.add_argument("--data-path", default="/datasets01/imagenet_full_size/061417/", type=str, help="dataset path")
    parser.add_argument("--model", default="resnet18", type=str, help="model name")
    parser.add_argument("--device", default="cuda", type=str, help="device (Use cuda or cpu Default: cuda)")
    parser.add_argument(
        "-b", "--batch-size", default=32, type=int, help="images per gpu, the total batch size is $NGPU x batch_size"
    )
    parser.add_argument("--epochs", default=90, type=int, metavar="N", help="number of total epochs to run")
    parser.add_argument(
        "-j", "--workers", default=16, type=int, metavar="N", help="number of data loading workers (default: 16)"
    )
    parser.add_argument("--opt", default="sgd", type=str, help="optimizer")
    parser.add_argument("--lr", default=0.1, type=float, help="initial learning rate")
    parser.add_argument("--momentum", default=0.9, type=float, metavar="M", help="momentum")
    parser.add_argument(
        "--wd",
        "--weight-decay",
        default=1e-4,
        type=float,
        metavar="W",
        help="weight decay (default: 1e-4)",
        dest="weight_decay",
    )
    parser.add_argument(
        "--norm-weight-decay",
        default=None,
        type=float,
        help="weight decay for Normalization layers (default: None, same value as --wd)",
    )
    parser.add_argument(
        "--label-smoothing", default=0.0, type=float, help="label smoothing (default: 0.0)", dest="label_smoothing"
    )
    parser.add_argument("--mixup-alpha", default=0.0, type=float, help="mixup alpha (default: 0.0)")
    parser.add_argument("--cutmix-alpha", default=0.0, type=float, help="cutmix alpha (default: 0.0)")
    parser.add_argument("--lr-scheduler", default="steplr", type=str, help="the lr scheduler (default: steplr)")
    parser.add_argument("--lr-warmup-epochs", default=0, type=int, help="the number of epochs to warmup (default: 0)")
    parser.add_argument(
        "--lr-warmup-method", default="constant", type=str, help="the warmup method (default: constant)"
    )
    parser.add_argument("--lr-warmup-decay", default=0.01, type=float, help="the decay for lr")
    parser.add_argument("--lr-step-size", default=30, type=int, help="decrease lr every step-size epochs")
    parser.add_argument("--lr-gamma", default=0.1, type=float, help="decrease lr by a factor of lr-gamma")
    parser.add_argument("--print-freq", default=10, type=int, help="print frequency")
    parser.add_argument("--output-dir", default=".", type=str, help="path to save outputs")
    parser.add_argument("--resume", default="", type=str, help="path of checkpoint")
    parser.add_argument("--start-epoch", default=0, type=int, metavar="N", help="start epoch")
    parser.add_argument(
        "--cache-dataset",
        dest="cache_dataset",
        help="Cache the datasets for quicker initialization. It also serializes the transforms",
        action="store_true",
    )
    parser.add_argument(
        "--sync-bn",
        dest="sync_bn",
        help="Use sync batch norm",
        action="store_true",
    )
    parser.add_argument(
        "--test-only",
        dest="test_only",
        help="Only test the model",
        action="store_true",
    )
    parser.add_argument(
        "--pretrained",
        dest="pretrained",
        help="Use pre-trained models from the modelzoo",
        action="store_true",
    )
    parser.add_argument("--auto-augment", default=None, type=str, help="auto augment policy (default: None)")
    parser.add_argument("--random-erase", default=0.0, type=float, help="random erasing probability (default: 0.0)")

    # Mixed precision training parameters
    parser.add_argument("--amp", action="store_true", help="Use torch.cuda.amp for mixed precision training")

    # distributed training parameters
    parser.add_argument("--world-size", default=1, type=int, help="number of distributed processes")
    parser.add_argument("--dist-url", default="env://", type=str, help="url used to set up distributed training")
    parser.add_argument(
        "--model-ema", action="store_true", help="enable tracking Exponential Moving Average of model parameters"
    )
    parser.add_argument(
        "--model-ema-steps",
        type=int,
        default=32,
        help="the number of iterations that controls how often to update the EMA model (default: 32)",
    )
    parser.add_argument(
        "--model-ema-decay",
        type=float,
        default=0.99998,
        help="decay factor for Exponential Moving Average of model parameters (default: 0.99998)",
    )
    parser.add_argument(
        "--use-deterministic-algorithms", action="store_true", help="Forces the use of deterministic algorithms only."
    )
    parser.add_argument(
        "--interpolation", default="bilinear", type=str, help="the interpolation method (default: bilinear)"
    )
    parser.add_argument(
        "--val-resize-size", default=256, type=int, help="the resize size used for validation (default: 256)"
    )
    parser.add_argument(
        "--val-crop-size", default=224, type=int, help="the central crop size used for validation (default: 224)"
    )
    parser.add_argument(
        "--train-crop-size", default=224, type=int, help="the random crop size used for training (default: 224)"
    )
    parser.add_argument("--clip-grad-norm", default=None, type=float, help="the maximum gradient norm (default None)")
    parser.add_argument("--ra-sampler", action="store_true", help="whether to use Repeated Augmentation in training")
    parser.add_argument(
        "--ra-reps", default=3, type=int, help="number of repetitions for Repeated Augmentation (default: 3)"
    )

    # Prototype models only
    parser.add_argument(
        "--prototype",
        dest="prototype",
        help="Use prototype model builders instead those from main area",
        action="store_true",
    )
    parser.add_argument("--weights", default=None, type=str, help="the weights enum name to load")

    return parser


if __name__ == "__main__":
    args = get_args_parser().parse_args()
    main(args)
"""

# %%
# !rm train.py
f = open("train.py", "w")
f.write(script1)
f.close()

# %% [markdown]
# ## Test command

# %%
# %%bash
# python train.py \
#     --data-path $DATA_PATH \
#     --epochs 1 \
#     --model mobilenet_v3_small --epochs 1 --opt rmsprop --batch-size 16 --lr 0.064  \
#     --weight-decay 0.00001 --lr-step-size 2 --lr-gamma 0.973 --auto-augment imagenet --random-erase 0.2
# Out:
# Not using distributed mode
# Namespace(amp=False, auto_augment='imagenet', batch_size=16, cache_dataset=False, clip_grad_norm=None, cutmix_alpha=0.0, data_path='CV_ML_take_home_task/screws_set', device='cuda', dist_url='env://', distributed=False, epochs=1, interpolation='bilinear', label_smoothing=0.0, lr=0.064, lr_gamma=0.973, lr_scheduler='steplr', lr_step_size=2, lr_warmup_decay=0.01, lr_warmup_epochs=0, lr_warmup_method='constant', mixup_alpha=0.0, model='mobilenet_v3_small', model_ema=False, model_ema_decay=0.99998, model_ema_steps=32, momentum=0.9, norm_weight_decay=None, opt='rmsprop', output_dir='.', pretrained=False, print_freq=10, prototype=False, ra_reps=3, ra_sampler=False, random_erase=0.2, resume='', start_epoch=0, sync_bn=False, test_only=False, train_crop_size=224, use_deterministic_algorithms=False, val_crop_size=224, val_resize_size=256, weight_decay=1e-05, weights=None, workers=16, world_size=1)
# Loading data
# Loading training data
# Took 0.0060672760009765625
# Loading validation data
# Creating data loaders
# Creating model
# Start training
# Epoch: [0]  [ 0/80]  eta: 0:04:29  lr: 0.064  img/s: 8.787503542035383  loss: 0.6916 (0.6916)  acc1: 37.5000 (37.5000)  acc2: 100.0000 (100.0000)  time: 3.3684  data: 1.5476  max mem: 457
# Epoch: [0]  [10/80]  eta: 0:00:27  lr: 0.064  img/s: 177.45170698686607  loss: 9.1731 (30.2428)  acc1: 50.0000 (50.5682)  acc2: 100.0000 (100.0000)  time: 0.3989  data: 0.1450  max mem: 457
# Epoch: [0]  [20/80]  eta: 0:00:15  lr: 0.064  img/s: 196.24368433211393  loss: 56.8910 (229.3560)  acc1: 50.0000 (50.5952)  acc2: 100.0000 (100.0000)  time: 0.1043  data: 0.0049  max mem: 457
# Epoch: [0]  [30/80]  eta: 0:00:10  lr: 0.064  img/s: 157.70913440636582  loss: 461.2214 (444.8237)  acc1: 43.7500 (50.2016)  acc2: 100.0000 (100.0000)  time: 0.1051  data: 0.0041  max mem: 457
# Epoch: [0]  [40/80]  eta: 0:00:07  lr: 0.064  img/s: 164.5526866850078  loss: 631.3340 (498.0452)  acc1: 50.0000 (51.5244)  acc2: 100.0000 (100.0000)  time: 0.1062  data: 0.0039  max mem: 457
# Epoch: [0]  [50/80]  eta: 0:00:04  lr: 0.064  img/s: 262.7001855490922  loss: 370.7211 (474.9087)  acc1: 56.2500 (51.8382)  acc2: 100.0000 (100.0000)  time: 0.1002  data: 0.0043  max mem: 457
# Epoch: [0]  [60/80]  eta: 0:00:02  lr: 0.064  img/s: 262.3899906162027  loss: 235.8287 (428.4215)  acc1: 56.2500 (52.2541)  acc2: 100.0000 (100.0000)  time: 0.0763  data: 0.0020  max mem: 457
# Epoch: [0]  [70/80]  eta: 0:00:01  lr: 0.064  img/s: 262.3007656919956  loss: 138.0848 (388.6945)  acc1: 50.0000 (51.6725)  acc2: 100.0000 (100.0000)  time: 0.0612  data: 0.0001  max mem: 457
# Epoch: [0] Total time: 0:00:10
# Test:   [ 0/14]  eta: 0:00:19  loss: 15662889041920.0000 (15662889041920.0000)  acc1: 0.0000 (0.0000)  acc2: 100.0000 (100.0000)  time: 1.3929  data: 1.3045  max mem: 457
# Test:  Total time: 0:00:02
# Test:  Acc@1 53.774 Acc@2 100.000
# Training time 0:00:13
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# ## inference.py

# %%
script2 = """
from PIL import Image
from torchvision.transforms.functional import InterpolationMode
import presets
import torch
from torch import nn
import argparse
import glob
import os
import torchvision

def load_image(img_path, args):
    val_resize_size, val_crop_size, train_crop_size = args.val_resize_size, args.val_crop_size, args.train_crop_size
    interpolation = InterpolationMode(args.interpolation)
    preprocessing = presets.ClassificationPresetEval(
        crop_size=val_crop_size, resize_size=val_resize_size, interpolation=interpolation
    )
    img = Image.open(img_path)
    img_t = preprocessing(img)
    return torch.unsqueeze(img_t, 0)

def load_model(model_path="checkpoint.pth"):
    dict_ = torch.load(model_path)
    args = dict_['args']
    model = torchvision.models.__dict__[args.model](pretrained=args.pretrained, num_classes=2)
    model.load_state_dict(dict_["model"])
    model.eval()
    return model, args

def main(input_dir, output_dir):
    classes = ["1","2"]
    model, args = load_model()

    input_files = glob.glob(input_dir + "/*")
    if len(input_files) == 0:
        print("No files found")
        return 1
    for img_path in input_files:
        input = load_image(img_path, args)
        outputs = model(input)
        _, pred = torch.max(outputs, 1)
        os.rename(img_path, output_dir+"/"+classes[pred[0]]+"/"+img_path.split("/")[-1])

def get_args_parser(add_help=True):    
    parser = argparse.ArgumentParser(description="PyTorch Classification Inference", add_help=add_help)
    parser.add_argument("--input_dir", default="example_directory_structure/input", type=str, help="input directory")
    parser.add_argument("--output_dir", default="example_directory_structure/output", type=str, help="output directory")

    return parser

if __name__ == "__main__":
    args = get_args_parser().parse_args()
    main(args.input_dir, args.output_dir)
"""

# %%
# !rm inference.py
f = open("inference.py", "w")
f.write(script2)
f.close()
# Out:
# rm: cannot remove 'inference.py': No such file or directory

# %% [markdown]
# ## Test command

# %%
# copy 1 sample image from each class
# !cp "{val_dir}/1/`ls {val_dir}/1 | head -n 1`" {input_dir}
# !cp "{val_dir}/2/`ls {val_dir}/2 | head -n 1`" {input_dir}

# %%
# %%bash
# python3 inference.py \
# --input_dir $INFER_PATH/input \
# --output_dir $INFER_PATH/output

# %% [markdown]
# ## Submit

# %%
# !ls *.py *.md | zip submission.zip -@
# Out:
#   adding: inference.py (deflated 60%)
#   adding: presets.py (deflated 75%)
#   adding: README.md (deflated 75%)
#   adding: sampler.py (deflated 64%)
#   adding: train.py (deflated 74%)
#   adding: train_quantization.py (deflated 73%)
#   adding: transforms.py (deflated 77%)
#   adding: utils.py (deflated 68%)

# %% [markdown]
# ## End
